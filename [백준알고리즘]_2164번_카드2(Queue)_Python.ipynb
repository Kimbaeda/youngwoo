# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimbaeda/youngwoo/blob/main/%5B%EB%B0%B1%EC%A4%80%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98%5D_2164%EB%B2%88_%EC%B9%B4%EB%93%9C2(Queue)_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
import sys

# input = sys.stdin.readline
N = int(input())

card_list = deque()


for i in range(1,N+1):
  card_list.append(i)

for _ in range(len(card_list)-1):
  card_list.popleft()
  card_list.rotate(-1)

print(card_list.pop())
# Out:
# 6
# 4

# %% [markdown]
# print(card_list)로 해서 틀렸다고 나왔는데
# pop()으로 값을 꺼내줘야했다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
card_list
# Out:
# deque([1, 2, 3, 4])

# %%
card_list.popleft()
# Out:
# 1

# %%
card_list
# Out:
# deque([2, 3, 4])

# %%
card_list.rotate(-1)

# %%
card_list
# Out:
# deque([3, 4, 2])

# %%
print(len(card_list))
# Out:
# 3

# %%
for _ in range(len(card_list)-1):
  card_list.popleft()
  card_list.rotate(-1)

print(card_list)
# Out:
# deque([4])
